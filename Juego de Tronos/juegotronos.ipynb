# %%
import pandas as pd

# %%
df = pd.read_csv("Game_of_Thrones.csv", index_col=0)

# %%
df.head()
# Out:
#         No. of Episode (Season)  No. of Episode (Overall)  \
# Season
# 1                             1                         1
# 1                             2                         2
# 1                             3                         3
# 1                             4                         4
# 1                             5                         5
#
#                          Title of the Episode  Running Time (Minutes)  \
# Season
# 1                            Winter Is Coming                      61
# 1                               The Kingsroad                      55
# 1                                   Lord Snow                      57
# 1       Cripples, Bastards, and Broken Things                      55
# 1                       The Wolf and the Lion                      54
#
#            Directed by                  Written by Original Air Date  \
# Season
# 1       Tim Van Patten  David Benioff, D. B. Weiss       17-Apr-2011
# ...

# %%
df.reset_index(inplace=True)

# %%
df.head(2)
# Out:
#    Season  No. of Episode (Season)  No. of Episode (Overall)  \
# 0       1                        1                         1
# 1       1                        2                         2
#
#   Title of the Episode  Running Time (Minutes)     Directed by  \
# 0     Winter Is Coming                      61  Tim Van Patten
# 1        The Kingsroad                      55  Tim Van Patten
#
#                    Written by Original Air Date  U.S. Viewers (Millions)  \
# 0  David Benioff, D. B. Weiss       17-Apr-2011                     2.22
# 1  David Benioff, D. B. Weiss       24-Apr-2011                     2.20
#
#         Music by Cinematography by         Editing by  IMDb Rating  \
# 0  Ramin Djawadi     Alik Sakharov  Oral Norrie Ottey          8.9
# 1  Ramin Djawadi     Alik Sakharov  Oral Norrie Ottey          8.6
#
#    Rotten Tomatoes Rating (Percentage)  Metacritic Ratings        Ordered  \
# 0                                  100                 9.1  March 2, 2010
# ...

# %%
df.sample(3)
# Out:
#     Season  No. of Episode (Season)  No. of Episode (Overall)  \
# 45       5                        6                        46
# 58       6                        9                        59
# 25       3                        6                        26
#
#          Title of the Episode  Running Time (Minutes)       Directed by  \
# 45  Unbowed, Unbent, Unbroken                      53    Jeremy Podeswa
# 58     Battle of the Bastards                      59  Miguel Sapochnik
# 25                  The Climb                      53     Alik Sakharov
#
#                     Written by Original Air Date  U.S. Viewers (Millions)  \
# 45                Bryan Cogman       17-May-2015                     6.24
# 58  David Benioff, D. B. Weiss       19-Jun-2016                     7.66
# 25  David Benioff, D. B. Weiss        5-May-2013                     5.50
#
#          Music by  Cinematography by         Editing by  IMDb Rating  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 19 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Season                               73 non-null     int64
#  1   No. of Episode (Season)              73 non-null     int64
#  2   No. of Episode (Overall)             73 non-null     int64
#  3   Title of the Episode                 73 non-null     object
#  4   Running Time (Minutes)               73 non-null     int64
#  5   Directed by                          73 non-null     object
#  6   Written by                           73 non-null     object
#  7   Original Air Date                    73 non-null     object
#  8   U.S. Viewers (Millions)              73 non-null     float64
#  9   Music by                             73 non-null     object
#  10  Cinematography by                    73 non-null     object
# ...

# %%
df.describe().T
# Out:
#                                      count       mean        std   min   25%  \
# Season                                73.0   4.205479   2.191897   1.0   2.0
# No. of Episode (Season)               73.0   5.191781   2.821827   1.0   3.0
# No. of Episode (Overall)              73.0  37.000000  21.217131   1.0  19.0
# Running Time (Minutes)                73.0  56.945205   7.185809  49.0  52.0
# U.S. Viewers (Millions)               73.0   6.447808   2.827372   2.2   3.9
# IMDb Rating                           73.0   8.741096   0.932565   4.0   8.5
# Rotten Tomatoes Rating (Percentage)   73.0  91.972603  11.499967  47.0  89.0
# Metacritic Ratings                    73.0   7.817808   1.684186   2.6   6.5
#
#                                        50%     75%     max
# Season                                4.00    6.00    8.00
# No. of Episode (Season)               5.00    7.00   10.00
# No. of Episode (Overall)             37.00   55.00   73.00
# ...

# %%
df["Rotten Tomatoes Rating"] = df["Rotten Tomatoes Rating (Percentage)"]/ 10

# %%
df.head(2)
# Out:
#    Season  No. of Episode (Season)  No. of Episode (Overall)  \
# 0       1                        1                         1
# 1       1                        2                         2
#
#   Title of the Episode  Running Time (Minutes)     Directed by  \
# 0     Winter Is Coming                      61  Tim Van Patten
# 1        The Kingsroad                      55  Tim Van Patten
#
#                    Written by Original Air Date  U.S. Viewers (Millions)  \
# 0  David Benioff, D. B. Weiss       17-Apr-2011                     2.22
# 1  David Benioff, D. B. Weiss       24-Apr-2011                     2.20
#
#         Music by Cinematography by         Editing by  IMDb Rating  \
# 0  Ramin Djawadi     Alik Sakharov  Oral Norrie Ottey          8.9
# 1  Ramin Djawadi     Alik Sakharov  Oral Norrie Ottey          8.6
#
#    Rotten Tomatoes Rating (Percentage)  Metacritic Ratings        Ordered  \
# 0                                  100                 9.1  March 2, 2010
# ...

# %%
df.columns
# Out:
# Index(['Season', 'No. of Episode (Season)', 'No. of Episode (Overall)',
#        'Title of the Episode', 'Running Time (Minutes)', 'Directed by',
#        'Written by', 'Original Air Date', 'U.S. Viewers (Millions)',
#        'Music by', 'Cinematography by', 'Editing by', 'IMDb Rating',
#        'Rotten Tomatoes Rating (Percentage)', 'Metacritic Ratings', 'Ordered',
#        'Filming Duration', 'Novel(s) Adapted', 'Synopsis',
#        'Rotten Tomatoes Rating'],
#       dtype='object')

# %%
df.drop(["No. of Episode (Overall)", "Rotten Tomatoes Rating (Percentage)", "Synopsis"], axis=1, inplace=True)

# %%
df.head(3)
# Out:
#    Season  No. of Episode (Season) Title of the Episode  \
# 0       1                        1     Winter Is Coming
# 1       1                        2        The Kingsroad
# 2       1                        3            Lord Snow
#
#    Running Time (Minutes)     Directed by                  Written by  \
# 0                      61  Tim Van Patten  David Benioff, D. B. Weiss
# 1                      55  Tim Van Patten  David Benioff, D. B. Weiss
# 2                      57      Brian Kirk  David Benioff, D. B. Weiss
#
#   Original Air Date  U.S. Viewers (Millions)       Music by Cinematography by  \
# 0       17-Apr-2011                     2.22  Ramin Djawadi     Alik Sakharov
# 1       24-Apr-2011                     2.20  Ramin Djawadi     Alik Sakharov
# 2        1-May-2011                     2.44  Ramin Djawadi  Marco Pontecorvo
#
#           Editing by  IMDb Rating  Metacritic Ratings        Ordered  \
# 0  Oral Norrie Ottey          8.9                 9.1  March 2, 2010
# ...

# %%
df.isnull().sum()
# Out:
# Season                     0
# No. of Episode (Season)    0
# Title of the Episode       0
# Running Time (Minutes)     0
# Directed by                0
# Written by                 0
# Original Air Date          0
# U.S. Viewers (Millions)    0
# Music by                   0
# Cinematography by          0
# Editing by                 0
# IMDb Rating                0
# Metacritic Ratings         0
# Ordered                    0
# Filming Duration           0
# Novel(s) Adapted           0
# Rotten Tomatoes Rating     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.to_csv("juego_de_tronos.csv")
